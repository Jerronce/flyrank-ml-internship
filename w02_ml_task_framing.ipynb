# %% [markdown]
# <a href="https://colab.research.google.com/github/Jerronce/flyrank-ml-internship/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jerronce/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
ml_task_type = "Classification"
print(f"Selected ML Task Type: {ml_task_type}")
# Out:
# Selected ML Task Type: Classification

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
target_variable = "intent_category"
print(f"Target or Proxy Variable: {target_variable}")
# Out:
# Target or Proxy Variable: intent_category

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
success_metric = "F1-Score (Macro)"
print(f"Chosen Success Metric: {success_metric}")
# Out:
# Chosen Success Metric: F1-Score (Macro)

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import os

# Load a small slice of the starter data to display the unit of analysis
data_path = '../../data/starter_sample.csv'
if os.path.exists(data_path):
    df = pd.read_csv(data_path)
    # Display the first 3 rows to show one row = one query unit
    display(df.head(3))
    print(f"DataFrame shape (Rows, Columns): {df.shape}")
else:
    # Fallback display representation if path varies
    mock_df = pd.DataFrame({
        'query_id': ['q_001', 'q_002'],
        'query_text': ['express route setup', 'fix mongoose error'],
        'intent_category': [0, 1]
    })
    display(mock_df)
    print("Displayed mock unit of analysis dataframe.")
# Out:
#   query_id           query_text  intent_category
# 0    q_001  express route setup                0
# 1    q_002   fix mongoose error                1
# Displayed mock unit of analysis dataframe.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
rule_based_limitation = "Rigid keyword matching fails on semantic variations."
print(f"Why ML is required: {rule_based_limitation}")
# Out:
# Why ML is required: Rigid keyword matching fails on semantic variations.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
