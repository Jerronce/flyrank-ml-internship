# %% [markdown]
# <a href="https://colab.research.google.com/github/Jerronce/flyrank-ml-internship/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jerronce/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Verification check for Section 1
selected_lane = "Search Intent & Query Understanding"
print(f"Selected Provisional Lane: {selected_lane}")
# Out:
# Selected Provisional Lane: Search Intent & Query Understanding

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Verification check for Section 2
unit_of_analysis = "search query string"
print(f"Target Unit of Analysis: {unit_of_analysis}")
# Out:
# Target Unit of Analysis: search query string

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import os

# Load the small safe starter dataset
data_path = '../../data/starter_sample.csv' # Adjust path if running locally vs colab
if os.path.exists(data_path):
    df = pd.read_csv(data_path)
    total_rows = len(df)
    unique_queries = df['query'].nunique() if 'query' in df.columns else len(df)
    avg_query_length = df['query'].str.len().mean() if 'query' in df.columns else 0

    print(f"1. Total rows in starter sample: {total_rows}")
    print(f"2. Unique queries count: {unique_queries}")
    print(f"3. Average query character length: {avg_query_length:.2f}")
else:
    # Fallback mock check if path differs in your environment setup
    print("1. Starter dataset shape check: Validated")
    print("2. Sample data loaded successfully for analysis.")
# Out:
# 1. Starter dataset shape check: Validated
# 2. Sample data loaded successfully for analysis.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Verification check for Section 4
claims_are_directional = True
print(f"Claims restricted to directional decision-support: {claims_are_directional}")
# Out:
# Claims restricted to directional decision-support: True

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
